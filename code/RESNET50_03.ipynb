# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from __future__ import print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ### 데이터 로드

# %%
trans = transforms.Compose([transforms.Resize((224,224)),
                           transforms.ToTensor(),
                           transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
                           ])

# %%
trainset = torchvision.datasets.ImageFolder(root = "/content/drive/MyDrive/Colab Notebooks/ml2021/data03/train",
                                           transform = trans)

train_loader = torch.utils.data.DataLoader(trainset, batch_size=8,
                                          shuffle=True)

# %%
validationset = torchvision.datasets.ImageFolder(root = "/content/drive/MyDrive/Colab Notebooks/ml2021/data03/valid",
                                           transform = trans)

val_loader = torch.utils.data.DataLoader(validationset, batch_size=8,
                                          shuffle=True)

# %%
testset = torchvision.datasets.ImageFolder(root = "/content/drive/MyDrive/Colab Notebooks/ml2021/data03/test",
                                           transform = trans)

test_loader = torch.utils.data.DataLoader(testset, batch_size = 8,
                                         shuffle = True)

# %% [markdown]
# ### 이미지 데이터 확인

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # 갱신이 될 때까지 잠시 기다립니다.

# %%
inputs, classes = next(iter(train_loader))
class_names = trainset.classes
# 배치로부터 격자 형태의 이미지를 만듭니다.
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# ## googlenet

# %%
import torchvision.models as models
net=models.resnet50(pretrained = True)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
num_classes = 3
num_ftrs = net.fc.in_features
net.fc = nn.Linear(num_ftrs,num_classes)
net.cuda()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=3, bias=True)
# )

# %%
import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(),lr=0.01, weight_decay=1e-6 ,momentum=0.9, nesterov=True)
#optimizer = optim.Adam(net.parameters(), lr = 0.01)

# %% [markdown]
# ## 학습

# %%
def val_eval(val_loader):
  class_correct = list(0. for i in range(1000))
  class_total = list(0. for i in range(1000))
  val_loss = 0.0
  with torch.no_grad():
      for i,data in enumerate(val_loader,0):
          images, labels = data
          images = images.cuda()
          labels = labels.cuda()

          optimizer.zero_grad()
          outputs = net(images)

          loss = criterion(outputs, labels)

          _, predicted = torch.max(outputs, 1)
          c = (predicted == labels).squeeze()
          for i in range(labels.size()[0]):
              label = labels[i].item()
              class_correct[label] += c[i].item()
              class_total[label] += 1
              val_loss += loss.item()
  val_acc = sum(class_correct) / sum(class_total) * 100


  print('-------------------------------val loss:', val_loss / len(val_loader))
  print("-------------------------------val Accuracy = ",val_acc)

# %%
for epoch in range(60):
  total = 0
  running_loss = 0.0
  correct = 0
  for i, data in enumerate(train_loader, 0):
      inputs, labels = data
      inputs, labels = inputs.cuda(), labels.cuda()
      imputs, lables = Variable(inputs.float().cuda()), Variable(labels.float().cuda())
      if i%100 == 0 :
          print("Training...",i)  


      optimizer.zero_grad()
      outputs = net(inputs)
      loss = criterion(outputs, labels)
      loss.backward()
      optimizer.step()
        
      max_index = outputs.max(dim=1)[1]
      correct += (max_index == labels).sum().item()
      total += labels.size(0)
      running_loss += loss.item()
      

      if i % len(train_loader) == len(train_loader) - 1:
        print('[epoc: %d, %5d] training loss: %.3f' %(epoch + 1, i + 1, running_loss / len(train_loader)))
        print("Training Accuracy = {}".format(100 * correct / total))
        val_eval(val_loader)
      
print('finish') 
PATH = '/content/drive/MyDrive/Colab Notebooks/ml2021/VGG19.pth'
torch.save(net.state_dict(), PATH)
# Out:
# Training... 0
# Training... 100
# [epoc: 1,   124] training loss: 0.966
# Training Accuracy = 64.17004048582996
# -------------------------------val loss: 7.160181489682967
# -------------------------------val Accuracy =  69.10569105691057
# Training... 0
# Training... 100
# [epoc: 2,   124] training loss: 0.669
# Training Accuracy = 73.98785425101215
# -------------------------------val loss: 6.337864234562843
# -------------------------------val Accuracy =  70.73170731707317
# Training... 0
# Training... 100
# [epoc: 3,   124] training loss: 0.616
# Training Accuracy = 75.20242914979757
# -------------------------------val loss: 5.585859679406689
# -------------------------------val Accuracy =  65.85365853658537
# Training... 0
# Training... 100
# [epoc: 4,   124] training loss: 0.590
# Training Accuracy = 75.40485829959515
# -------------------------------val loss: 6.972906452994192
# -------------------------------val Accuracy =  67.88617886178862
# Training... 0
# Training... 100
# [epoc: 5,   124] training loss: 0.566
# Training Accuracy = 77.7327935222672
# -------------------------------val loss: 6.169552022410977
# -------------------------------val Accuracy =  66.66666666666666
# Training... 0
# Training... 100
# [epoc: 6,   124] training loss: 0.573
# Training Accuracy = 76.11336032388664
# -------------------------------val loss: 5.6610939271988405
# -------------------------------val Accuracy =  69.91869918699187
# Training... 0
# Training... 100
# [epoc: 7,   124] training loss: 0.521
# Training Accuracy = 79.65587044534414
# -------------------------------val loss: 5.702502196834933
# -------------------------------val Accuracy =  67.07317073170732
# Training... 0
# Training... 100
# [epoc: 8,   124] training loss: 0.472
# Training Accuracy = 80.97165991902834
# -------------------------------val loss: 6.252362533923118
# -------------------------------val Accuracy =  71.13821138211382
# Training... 0
# Training... 100
# [epoc: 9,   124] training loss: 0.437
# Training Accuracy = 82.89473684210526
# -------------------------------val loss: 4.324742926705268
# -------------------------------val Accuracy =  72.35772357723577
# Training... 0
# Training... 100
# [epoc: 10,   124] training loss: 0.456
# Training Accuracy = 80.97165991902834
# -------------------------------val loss: 6.147289391486876
# -------------------------------val Accuracy =  70.73170731707317
# Training... 0
# Training... 100
# [epoc: 11,   124] training loss: 0.391
# Training Accuracy = 85.82995951417004
# -------------------------------val loss: 5.836288594430493
# -------------------------------val Accuracy =  67.88617886178862
# Training... 0
# Training... 100
# [epoc: 12,   124] training loss: 0.367
# Training Accuracy = 86.43724696356276
# -------------------------------val loss: 5.569701521627365
# -------------------------------val Accuracy =  72.76422764227642
# Training... 0
# Training... 100
# [epoc: 13,   124] training loss: 0.287
# Training Accuracy = 89.27125506072875
# -------------------------------val loss: 5.218762791925861
# -------------------------------val Accuracy =  72.76422764227642
# Training... 0
# Training... 100
# [epoc: 14,   124] training loss: 0.334
# Training Accuracy = 85.82995951417004
# -------------------------------val loss: 7.747196428237423
# -------------------------------val Accuracy =  69.10569105691057
# Training... 0
# Training... 100
# [epoc: 15,   124] training loss: 0.369
# Training Accuracy = 86.43724696356276
# -------------------------------val loss: 7.5663423153661915
# -------------------------------val Accuracy =  70.32520325203252
# Training... 0
# Training... 100
# [epoc: 16,   124] training loss: 0.510
# Training Accuracy = 79.55465587044534
# -------------------------------val loss: 5.5245110296433975
# -------------------------------val Accuracy =  68.69918699186992
# Training... 0
# Training... 100
# [epoc: 17,   124] training loss: 0.363
# Training Accuracy = 86.23481781376518
# -------------------------------val loss: 6.940675789310086
# -------------------------------val Accuracy =  62.601626016260155
# Training... 0
# Training... 100
# [epoc: 18,   124] training loss: 0.299
# Training Accuracy = 87.95546558704453
# -------------------------------val loss: 7.925853182231227
# -------------------------------val Accuracy =  73.57723577235772
# Training... 0
# Training... 100
# [epoc: 19,   124] training loss: 0.262
# Training Accuracy = 89.67611336032388
# -------------------------------val loss: 9.2136654046274
# -------------------------------val Accuracy =  59.34959349593496
# Training... 0
# Training... 100
# [epoc: 20,   124] training loss: 0.202
# Training Accuracy = 91.80161943319838
# -------------------------------val loss: 7.9774775581975135
# -------------------------------val Accuracy =  70.32520325203252
# Training... 0
# Training... 100
# [epoc: 21,   124] training loss: 0.250
# Training Accuracy = 91.19433198380567
# -------------------------------val loss: 8.408426222301298
# -------------------------------val Accuracy =  67.47967479674797
# Training... 0
# Training... 100
# [epoc: 22,   124] training loss: 0.159
# Training Accuracy = 94.23076923076923
# -------------------------------val loss: 10.230162048532117
# -------------------------------val Accuracy =  71.13821138211382
# Training... 0
# Training... 100
# [epoc: 23,   124] training loss: 0.121
# Training Accuracy = 95.24291497975709
# -------------------------------val loss: 9.262328290170238
# -------------------------------val Accuracy =  69.91869918699187
# Training... 0
# Training... 100
# [epoc: 24,   124] training loss: 0.151
# Training Accuracy = 95.04048582995951
# -------------------------------val loss: 10.465781044575476
# -------------------------------val Accuracy =  69.91869918699187
# Training... 0
# Training... 100
# [epoc: 25,   124] training loss: 0.236
# Training Accuracy = 91.49797570850203
# -------------------------------val loss: 10.008916950994923
# -------------------------------val Accuracy =  68.29268292682927
# Training... 0
# Training... 100
# [epoc: 26,   124] training loss: 0.099
# Training Accuracy = 96.76113360323886
# -------------------------------val loss: 9.150655879128363
# -------------------------------val Accuracy =  71.54471544715447
# Training... 0
# Training... 100
# [epoc: 27,   124] training loss: 0.086
# Training Accuracy = 97.67206477732793
# -------------------------------val loss: 10.326459123242286
# -------------------------------val Accuracy =  69.51219512195121
# Training... 0
# Training... 100
# [epoc: 28,   124] training loss: 0.080
# Training Accuracy = 97.8744939271255
# -------------------------------val loss: 8.991836297235661
# -------------------------------val Accuracy =  73.98373983739837
# Training... 0
# Training... 100
# [epoc: 29,   124] training loss: 0.117
# Training Accuracy = 95.34412955465586
# -------------------------------val loss: 10.404582422587179
# -------------------------------val Accuracy =  72.35772357723577
# Training... 0
# Training... 100
# [epoc: 30,   124] training loss: 0.083
# Training Accuracy = 96.86234817813765
# -------------------------------val loss: 12.887214672180914
# -------------------------------val Accuracy =  71.95121951219512
# Training... 0
# Training... 100
# [epoc: 31,   124] training loss: 0.057
# Training Accuracy = 98.38056680161944
# -------------------------------val loss: 11.314053735906079
# -------------------------------val Accuracy =  73.57723577235772
# Training... 0
# Training... 100
# [epoc: 32,   124] training loss: 0.030
# Training Accuracy = 99.19028340080972
# -------------------------------val loss: 12.46018343875485
# -------------------------------val Accuracy =  71.95121951219512
# Training... 0
# Training... 100
# [epoc: 33,   124] training loss: 0.024
# Training Accuracy = 99.2914979757085
# -------------------------------val loss: 13.357569875255708
# -------------------------------val Accuracy =  70.32520325203252
# Training... 0
# Training... 100
# [epoc: 34,   124] training loss: 0.054
# Training Accuracy = 98.17813765182186
# -------------------------------val loss: 13.26086441887122
# -------------------------------val Accuracy =  71.13821138211382
# Training... 0
# Training... 100
# [epoc: 35,   124] training loss: 0.051
# Training Accuracy = 98.38056680161944
# -------------------------------val loss: 13.629178551896926
# -------------------------------val Accuracy =  69.51219512195121
# Training... 0
# Training... 100
# [epoc: 36,   124] training loss: 0.040
# Training Accuracy = 98.48178137651821
# -------------------------------val loss: 14.589069933540397
# -------------------------------val Accuracy =  73.17073170731707
# Training... 0
# Training... 100
# [epoc: 37,   124] training loss: 0.043
# Training Accuracy = 98.38056680161944
# -------------------------------val loss: 11.12826124698885
# -------------------------------val Accuracy =  71.13821138211382
# Training... 0
# Training... 100
# [epoc: 38,   124] training loss: 0.127
# Training Accuracy = 95.74898785425101
# -------------------------------val loss: 11.018912807587654
# -------------------------------val Accuracy =  71.54471544715447
# Training... 0
# Training... 100
# [epoc: 39,   124] training loss: 0.026
# Training Accuracy = 99.39271255060729
# -------------------------------val loss: 13.660167749355276
# -------------------------------val Accuracy =  73.17073170731707
# Training... 0
# Training... 100
# [epoc: 40,   124] training loss: 0.027
# Training Accuracy = 98.6842105263158
# -------------------------------val loss: 14.622743410929557
# -------------------------------val Accuracy =  67.47967479674797
# Training... 0
# Training... 100
# [epoc: 41,   124] training loss: 0.058
# Training Accuracy = 97.97570850202429
# -------------------------------val loss: 13.179513903875504
# -------------------------------val Accuracy =  71.54471544715447
# Training... 0
# Training... 100
# [epoc: 42,   124] training loss: 0.044
# Training Accuracy = 98.582995951417
# -------------------------------val loss: 14.352996538242985
# -------------------------------val Accuracy =  68.69918699186992
# Training... 0
# Training... 100
# [epoc: 43,   124] training loss: 0.018
# Training Accuracy = 99.59514170040485
# -------------------------------val loss: 15.378491547799879
# -------------------------------val Accuracy =  69.51219512195121
# Training... 0
# Training... 100
# [epoc: 44,   124] training loss: 0.003
# Training Accuracy = 100.0
# -------------------------------val loss: 16.16969926751429
# -------------------------------val Accuracy =  71.54471544715447
# Training... 0
# Training... 100
# [epoc: 45,   124] training loss: 0.008
# Training Accuracy = 99.59514170040485
# -------------------------------val loss: 15.89113125938081
# -------------------------------val Accuracy =  71.54471544715447
# Training... 0
# Training... 100
# [epoc: 46,   124] training loss: 0.010
# Training Accuracy = 99.89878542510121
# -------------------------------val loss: 15.316381396785859
# -------------------------------val Accuracy =  69.10569105691057
# Training... 0
# Training... 100
# [epoc: 47,   124] training loss: 0.018
# Training Accuracy = 99.49392712550608
# -------------------------------val loss: 15.26601936932533
# -------------------------------val Accuracy =  71.54471544715447
# Training... 0
# Training... 100
# [epoc: 48,   124] training loss: 0.036
# Training Accuracy = 98.6842105263158
# -------------------------------val loss: 17.246276008025294
# -------------------------------val Accuracy =  68.69918699186992
# Training... 0
# Training... 100
# [epoc: 49,   124] training loss: 0.012
# Training Accuracy = 99.79757085020243
# -------------------------------val loss: 17.09297622788337
# -------------------------------val Accuracy =  71.54471544715447
# Training... 0
# Training... 100
# [epoc: 50,   124] training loss: 0.019
# Training Accuracy = 99.19028340080972
# -------------------------------val loss: 15.482415333870918
# -------------------------------val Accuracy =  69.10569105691057
# Training... 0
# Training... 100
# [epoc: 51,   124] training loss: 0.049
# Training Accuracy = 98.38056680161944
# -------------------------------val loss: 14.853057247977103
# -------------------------------val Accuracy =  66.66666666666666
# Training... 0
# Training... 100
# [epoc: 52,   124] training loss: 0.011
# Training Accuracy = 99.69635627530364
# -------------------------------val loss: 15.453662241718941
# -------------------------------val Accuracy =  72.76422764227642
# Training... 0
# Training... 100
# [epoc: 53,   124] training loss: 0.003
# Training Accuracy = 100.0
# -------------------------------val loss: 16.31859177735544
# -------------------------------val Accuracy =  74.39024390243902
# Training... 0
# Training... 100
# [epoc: 54,   124] training loss: 0.002
# Training Accuracy = 100.0
# -------------------------------val loss: 16.600473932200863
# -------------------------------val Accuracy =  73.98373983739837
# Training... 0
# Training... 100
# [epoc: 55,   124] training loss: 0.006
# Training Accuracy = 99.79757085020243
# -------------------------------val loss: 16.424250953890866
# -------------------------------val Accuracy =  73.98373983739837
# Training... 0
# Training... 100
# [epoc: 56,   124] training loss: 0.003
# Training Accuracy = 100.0
# -------------------------------val loss: 16.128489904105663
# -------------------------------val Accuracy =  71.54471544715447
# Training... 0
# Training... 100
# [epoc: 57,   124] training loss: 0.009
# Training Accuracy = 99.69635627530364
# -------------------------------val loss: 15.68332073932153
# -------------------------------val Accuracy =  73.57723577235772
# Training... 0
# Training... 100
# [epoc: 58,   124] training loss: 0.010
# Training Accuracy = 99.59514170040485
# -------------------------------val loss: 16.520381819817327
# -------------------------------val Accuracy =  71.95121951219512
# Training... 0
# Training... 100
# [epoc: 59,   124] training loss: 0.041
# Training Accuracy = 98.78542510121457
# -------------------------------val loss: 16.814243596407675
# -------------------------------val Accuracy =  74.39024390243902
# Training... 0
# Training... 100
# [epoc: 60,   124] training loss: 0.003
# Training Accuracy = 99.89878542510121
# -------------------------------val loss: 16.663927326279303
# -------------------------------val Accuracy =  72.35772357723577
# finish

# %% [markdown]
# ### 정확도 확인

# %%
correct = 0
total = 0
with torch.no_grad():
    for i, data in enumerate(test_loader, 0):
        images, labels = data
        images, labels = images.float().cuda(), labels.float().cuda()

        outputs = net(images)
        max_index = outputs.max(dim=1)[1]
        total += labels.size(0)
        correct += (max_index == labels).sum().item()

print('Accuracy of Test: %d %%' % (100 * correct / total))
# Out:
# Accuracy of Test: 77 %
